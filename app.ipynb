# %%
import aws_cdk as cdk
from cdk_ml_ci.cdk_ml_ci_stack import CdkMlCiStack
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import aws_cdk as cdk
#       2 from cdk_ml_ci.cdk_ml_ci_stack import CdkMlCiStack
#
# File ~/mambaforge/envs/aws/lib/python3.12/site-packages/aws_cdk/__init__.py:1612
#    1609             else:
#    1610                 typeguard.check_type(value=value, expected_type=expected_type, collection_check_strategy=typeguard.CollectionCheckStrategy.ALL_ITEMS) # type:ignore
# -> 1612 from ._jsii import *
#    1614 import constructs as _constructs_77d1e7e8
#    1615 from .cloud_assembly_schema import (
#    1616     AmiContextQuery as _AmiContextQuery_74bf4b1b,
#    1617     AssetManifestOptions as _AssetManifestOptions_73b93270,
#    (...)   1635     VpcContextQuery as _VpcContextQuery_a193c650,
#    1636 )
#
# File ~/mambaforge/envs/aws/lib/python3.12/site-packages/aws_cdk/_jsii/__init__.py:31
# ...

# %%
app = cdk.App()
CdkMlCiStack(app, "CdkMlCiStack", env=cdk.Environment(
    account="123456789012",
    region="us-east-1"
))
app.synth()
